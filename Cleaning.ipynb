# %%
import pandas as pd

# %%
import numpy as np

# %%
oo = pd.read_csv("/Users/gouribenni/COURSES SEM 2/GWAR/PROJECTS/drive-download-20230418T181140Z-001/Order.csv")

# %%
oo
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                       3.0                            4.0
# 1       TRANSFER                       5.0                            4.0
# 2           CASH                       4.0                            4.0
# 3          DEBIT                       3.0                            4.0
# 4        PAYMENT                       2.0                            4.0
# ...          ...                       ...                            ...
# 180651       NaN                       NaN                            NaN
# 180652       NaN                       NaN                            NaN
# 180653       NaN                       NaN                            NaN
# 180654       NaN                       NaN                            NaN
# 180655       NaN                       NaN                            NaN
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
oo.isnull().sum()
# Out:
# Type                                 74
# Days for shipping (real)             74
# Days for shipment (scheduled)        74
# Benefit per order                    74
# Sales per customer                   74
# Delivery Status                      74
# Late_delivery_risk                   74
# Category Id                          74
# Category Name                        93
# Customer City                        87
# Customer Country                     91
# Customer Email                       87
# Customer Fname                       94
# Customer Id                          94
# Customer Lname                       97
# Customer Password                    94
# Customer Segment                     99
# Customer State                       89
# Customer Street                      74
# Customer Zipcode                     77
# Department Id                        74
# Department Name                      74
# Latitude                             98
# ...

# %%
oo.dropna(inplace=True)

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180656 entries, 0 to 180655
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180582 non-null  object
#  1   Days for shipping (real)       180582 non-null  float64
#  2   Days for shipment (scheduled)  180582 non-null  float64
#  3   Benefit per order              180582 non-null  float64
#  4   Sales per customer             180582 non-null  float64
#  5   Delivery Status                180582 non-null  object
#  6   Late_delivery_risk             180582 non-null  float64
#  7   Category Id                    180582 non-null  float64
#  8   Category Name                  180563 non-null  object
#  9   Customer City                  180569 non-null  object
#  10  Customer Country               180565 non-null  object
#  11  Customer Email                 180569 non-null  object
# ...

# %%
oo
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 55       PAYMENT                       2.0                            2.0
# 56       PAYMENT                       5.0                            2.0
# 57       PAYMENT                       6.0                            2.0
# 58       PAYMENT                       4.0                            2.0
# 183     TRANSFER                       5.0                            4.0
# ...          ...                       ...                            ...
# 179402  TRANSFER                       5.0                            4.0
# 179403  TRANSFER                       3.0                            4.0
# 179404  TRANSFER                       5.0                            4.0
# 179405  TRANSFER                       3.0                            4.0
# 179406  TRANSFER                       4.0                            4.0
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
oo.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
del oo['Order Zipcode']

# %%
oo.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
pp = pd.read_csv("/Users/gouribenni/COURSES SEM 2/GWAR/PROJECTS/drive-download-20230418T181140Z-001/Product.csv")

# %%
pp
# Out:
#         Order Id  Product Card Id  Product Category Id  Product Description  \
# 0        77202.0           1360.0                 73.0                  NaN
# 1        75939.0           1360.0                 73.0                  NaN
# 2        75938.0           1360.0                 73.0                  NaN
# 3        75937.0           1360.0                 73.0                  NaN
# 4        75936.0           1360.0                 73.0                  NaN
# ...          ...              ...                  ...                  ...
# 180651       NaN           1004.0                 45.0                  NaN
# 180652       NaN           1004.0                 45.0                  NaN
# 180653       NaN           1004.0                 45.0                  NaN
# 180654       NaN           1004.0                 45.0                  NaN
# 180655       NaN           1004.0                 45.0                  NaN
#
# ...

# %%
pp.isnull().sum()
# Out:
# Order Id                  137
# Product Card Id            11
# Product Category Id        26
# Product Description    180656
# Product Image              50
# Product Name               56
# Product Price              29
# Product Status              0
# Shipping Mode              17
# dtype: int64

# %%
df500 = pd.read_csv("cleaned_supply_chain.csv")

df400 = merged_df = df_product.merge(df_order, on='Order ID')  
df500
# Out:
#             Type   Delivery_Status Customer_City Customer_Country  \
# 0          DEBIT  Advance shipping        Caguas      Puerto Rico
# 1       TRANSFER     Late delivery        Caguas      Puerto Rico
# 2           CASH  Shipping on time      San Jose          EE. UU.
# 3          DEBIT  Advance shipping   Los Angeles          EE. UU.
# 4        PAYMENT  Advance shipping        Caguas      Puerto Rico
# ...          ...               ...           ...              ...
# 180514      CASH  Shipping on time      Brooklyn          EE. UU.
# 180515     DEBIT     Late delivery   Bakersfield          EE. UU.
# 180516  TRANSFER     Late delivery       Bristol          EE. UU.
# 180517   PAYMENT  Advance shipping        Caguas      Puerto Rico
# 180518   PAYMENT  Shipping on time        Caguas      Puerto Rico
#
#        Customer_Segment Customer_State             Customer_Street  \
# 0              Consumer             PR    5365 Noble Nectar Island
# ...

# %%
pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180656 entries, 0 to 180655
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Order Id             180519 non-null  float64
#  1   Product Card Id      180645 non-null  float64
#  2   Product Category Id  180630 non-null  float64
#  3   Product Description  0 non-null       float64
#  4   Product Image        180606 non-null  object
#  5   Product Name         180600 non-null  object
#  6   Product Price        180627 non-null  float64
#  7   Product Status       180656 non-null  int64
#  8   Shipping Mode        180639 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 12.4+ MB

# %%
del pp['Product Description']

# %%
pp.isnull().sum()
# Out:
# Order Id               0.0
# Product Card Id        0.0
# Product Category Id    0.0
# Product Image          0.0
# Product Name           0.0
# Product Price          0.0
# Product Status         0.0
# Shipping Mode          0.0
# dtype: float64

# %%
df1.apply(pd.to_numeric)
# Out:
# Empty DataFrame
# Columns: [Order Id, Product Card Id, Product Category Id, Product Image, Product Name, Product Price, Product Status, Shipping Mode]
# Index: []

# %%
df1.isnull().sum()
# Out:
# Order Id               0.0
# Product Card Id        0.0
# Product Category Id    0.0
# Product Image          0.0
# Product Name           0.0
# Product Price          0.0
# Product Status         0.0
# Shipping Mode          0.0
# dtype: float64

# %%
cols = ['Order Id', 'Product Card Id', 'Product Category Id', 'Product Image', 'Product Name', 'Product Price',
       'Product Status', 'Shipping Mode']
df1[cols] = df1[cols].applymap(np.int64)
print(df)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 55       PAYMENT                       2.0                            2.0
# 56       PAYMENT                       5.0                            2.0
# 57       PAYMENT                       6.0                            2.0
# 58       PAYMENT                       4.0                            2.0
# 183     TRANSFER                       5.0                            4.0
# ...          ...                       ...                            ...
# 179402  TRANSFER                       5.0                            4.0
# 179403  TRANSFER                       3.0                            4.0
# 179404  TRANSFER                       5.0                            4.0
# 179405  TRANSFER                       3.0                            4.0
# 179406  TRANSFER                       4.0                            4.0
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
df1.isnull().sum()
# Out:
# Order Id               0.0
# Product Card Id        0.0
# Product Category Id    0.0
# Product Image          0.0
# Product Name           0.0
# Product Price          0.0
# Product Status         0.0
# Shipping Mode          0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df[['shipping date (DateOrders)', 'order date (DateOrders)', 'Order Id']].head(15)
# Out:
#     shipping date (DateOrders) order date (DateOrders)  Order Id
# 55                  2016-06-13              2016-06-11     36146
# 56                  2016-08-29              2016-08-24     41234
# 57                  2016-04-19              2016-04-13     32090
# 58                  2016-05-26              2016-05-22     34773
# 183                 2016-05-13              2016-05-08     33824
# 184                 2016-04-07              2016-04-02     31364
# 185                 2016-08-20              2016-08-14     40495
# 186                 2016-04-07              2016-04-02     31364
# 187                 2016-05-20              2016-05-18     34506
# 188                 2016-05-08              2016-05-05     33607
# 189                 2016-04-24              2016-04-21     32617
# 190                 2016-07-03              2016-07-01     37496
# 191                 2016-04-24              2016-04-21     32617
# ...

# %%
df['date'] = pd.to_datetime(df['shipping date (DateOrders)']).dt.date
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 55       PAYMENT                       2.0                            2.0
# 56       PAYMENT                       5.0                            2.0
# 57       PAYMENT                       6.0                            2.0
# 58       PAYMENT                       4.0                            2.0
# 183     TRANSFER                       5.0                            4.0
# ...          ...                       ...                            ...
# 179402  TRANSFER                       5.0                            4.0
# 179403  TRANSFER                       3.0                            4.0
# 179404  TRANSFER                       5.0                            4.0
# 179405  TRANSFER                       3.0                            4.0
# 179406  TRANSFER                       4.0                            4.0
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
df[['shipping date (DateOrders)','Order Id']]
# Out:
#        shipping date (DateOrders)  Order Id
# 55                     2016-06-13     36146
# 56                     2016-08-29     41234
# 57                     2016-04-19     32090
# 58                     2016-05-26     34773
# 183                    2016-05-13     33824
# ...                           ...       ...
# 179402                 2016-08-21     40634
# 179403                 2016-07-12     38032
# 179404                 2016-05-10     33619
# 179405                 2016-07-12     38032
# 179406                 2016-07-05     37493
#
# [24840 rows x 2 columns]

# %%
df['DateOrders'] = df['shipping date (DateOrders)'].str.split(' ', expand=True)[0]

# %%
df[['shipping date (DateOrders)']
# Out:
#        shipping date (DateOrders)  Order Id
# 55                     2016-06-13     36146
# 56                     2016-08-29     41234
# 57                     2016-04-19     32090
# 58                     2016-05-26     34773
# 183                    2016-05-13     33824
# ...                           ...       ...
# 179402                 2016-08-21     40634
# 179403                 2016-07-12     38032
# 179404                 2016-05-10     33619
# 179405                 2016-07-12     38032
# 179406                 2016-07-05     37493
#
# [24840 rows x 2 columns]

# %%
df['Shipping Date'] = pd.to_datetime(df['shipping date (DateOrders)'])

# %%
df['Shipping Date'].dt.date
# Out:
# 55        2016-06-13
# 56        2016-08-29
# 57        2016-04-19
# 58        2016-05-26
# 183       2016-05-13
#              ...
# 179402    2016-08-21
# 179403    2016-07-12
# 179404    2016-05-10
# 179405    2016-07-12
# 179406    2016-07-05
# Name: Shipping Date, Length: 24840, dtype: object

# %%
df['shipping date (DateOrders)'] = df['Shipping Date'].dt.date

# %%
df[['shipping date (DateOrders)']]
# Out:
#        shipping date (DateOrders)
# 55                     2016-06-13
# 56                     2016-08-29
# 57                     2016-04-19
# 58                     2016-05-26
# 183                    2016-05-13
# ...                           ...
# 179402                 2016-08-21
# 179403                 2016-07-12
# 179404                 2016-05-10
# 179405                 2016-07-12
# 179406                 2016-07-05
#
# [24840 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
df['Order Date'] = pd.to_datetime(df['order date (DateOrders)'])

# %%
df['Order Date'].dt.date
# Out:
# 55        2016-06-11
# 56        2016-08-24
# 57        2016-04-13
# 58        2016-05-22
# 183       2016-05-08
#              ...
# 179402    2016-08-16
# 179403    2016-07-09
# 179404    2016-05-05
# 179405    2016-07-09
# 179406    2016-07-01
# Name: Order Date, Length: 24840, dtype: object

# %%
df['order date (DateOrders)'] = df['Order Date'].dt.date

# %%
df[['order date (DateOrders)', 'shipping date (DateOrders)']]
# Out:
#        order date (DateOrders) shipping date (DateOrders)
# 55                  2016-06-11                 2016-06-13
# 56                  2016-08-24                 2016-08-29
# 57                  2016-04-13                 2016-04-19
# 58                  2016-05-22                 2016-05-26
# 183                 2016-05-08                 2016-05-13
# ...                        ...                        ...
# 179402              2016-08-16                 2016-08-21
# 179403              2016-07-09                 2016-07-12
# 179404              2016-05-05                 2016-05-10
# 179405              2016-07-09                 2016-07-12
# 179406              2016-07-01                 2016-07-05
#
# [24840 rows x 2 columns]

# %%
df.dtypes
# Out:
# Type                                     object
# Days for shipping (real)                float64
# Days for shipment (scheduled)           float64
# Benefit per order                       float64
# Sales per customer                      float64
# Delivery Status                          object
# Late_delivery_risk                      float64
# Category Id                             float64
# Category Name                            object
# Customer City                            object
# Customer Country                         object
# Customer Email                           object
# Customer Fname                           object
# Customer Id                             float64
# Customer Lname                           object
# Customer Password                        object
# Customer Segment                         object
# Customer State                           object
# Customer Street                          object
# Customer Zipcode                        float64
# ...

# %%
df['Order Id'] = df['Order Id'].apply(np.int64)

# %%
df[['Order Id']].head(15)
# Out:
#      Order Id
# 55      36146
# 56      41234
# 57      32090
# 58      34773
# 183     33824
# 184     31364
# 185     40495
# 186     31364
# 187     34506
# 188     33607
# 189     32617
# 190     37496
# 191     32617
# 193     33824
# 196     39271

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 55       PAYMENT                       2.0                            2.0
# 56       PAYMENT                       5.0                            2.0
# 57       PAYMENT                       6.0                            2.0
# 58       PAYMENT                       4.0                            2.0
# 183     TRANSFER                       5.0                            4.0
# ...          ...                       ...                            ...
# 179402  TRANSFER                       5.0                            4.0
# 179403  TRANSFER                       3.0                            4.0
# 179404  TRANSFER                       5.0                            4.0
# 179405  TRANSFER                       3.0                            4.0
# 179406  TRANSFER                       4.0                            4.0
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
oo
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 55       PAYMENT                       2.0                            2.0
# 56       PAYMENT                       5.0                            2.0
# 57       PAYMENT                       6.0                            2.0
# 58       PAYMENT                       4.0                            2.0
# 183     TRANSFER                       5.0                            4.0
# ...          ...                       ...                            ...
# 179402  TRANSFER                       5.0                            4.0
# 179403  TRANSFER                       3.0                            4.0
# 179404  TRANSFER                       5.0                            4.0
# 179405  TRANSFER                       3.0                            4.0
# 179406  TRANSFER                       4.0                            4.0
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

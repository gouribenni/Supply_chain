# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f6/0w9l71rj07jdyn9y6cldqdcw0000gn/T/ipykernel_43037/12728935.py in <module>
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 import squarify
#
# ModuleNotFoundError: No module named 'squarify'

# %%
df = pd.read_csv("/Users/gouribenni/COURSES SEM 2/GWAR/PROJECTS/cleaned_supply_chain.csv")

# %%
df
# Out:
#             Type   Delivery_Status Customer_City Customer_Country  \
# 0          DEBIT  Advance shipping        Caguas      Puerto Rico
# 1       TRANSFER     Late delivery        Caguas      Puerto Rico
# 2           CASH  Shipping on time      San Jose          EE. UU.
# 3          DEBIT  Advance shipping   Los Angeles          EE. UU.
# 4        PAYMENT  Advance shipping        Caguas      Puerto Rico
# ...          ...               ...           ...              ...
# 180514      CASH  Shipping on time      Brooklyn          EE. UU.
# 180515     DEBIT     Late delivery   Bakersfield          EE. UU.
# 180516  TRANSFER     Late delivery       Bristol          EE. UU.
# 180517   PAYMENT  Advance shipping        Caguas      Puerto Rico
# 180518   PAYMENT  Shipping on time        Caguas      Puerto Rico
#
#        Customer_Segment Customer_State             Customer_Street  \
# 0              Consumer             PR    5365 Noble Nectar Island
# ...

# %%
df.isnull().sum()
# Out:
# Type                             0
# Delivery_Status                  0
# Customer_City                    0
# Customer_Country                 0
# Customer_Segment                 0
# Customer_State                   0
# Customer_Street                  0
# Department_Name                  0
# Market                           0
# Order_City                       0
# Order_Country                    0
# Order_Region                     0
# Order_State                      0
# Order_Status                     0
# Product_Name                     0
# Shipping_Mode                    0
# Category_Id                      0
# Category_Name                    0
# Customer_Id                      0
# Department_Id                    0
# Order_Customer_Id                0
# Order_Id                         0
# Order_Item_Cardprod_Id           0
# Order_Item_Id                    0
# Product_Card_Id                  0
# Product_Category_Id              0
# Days_for_shipping_(real)         0
# ...

# %%
df.shape
# Out:
# (180519, 44)

# %%
df.corr()
# Out:
#                                Category_Id  Customer_Id  Department_Id  \
# Category_Id                       1.000000     0.274633       0.888835
# Customer_Id                       0.274633     1.000000       0.136897
# Department_Id                     0.888835     0.136897       1.000000
# Order_Customer_Id                 0.274633     1.000000       0.136897
# Order_Id                          0.198496     0.204821       0.106757
# Order_Item_Cardprod_Id            0.991092     0.228039       0.906117
# Order_Item_Id                     0.186796     0.191814       0.101676
# Product_Card_Id                   0.991092     0.228039       0.906117
# Product_Category_Id               1.000000     0.274633       0.888835
# Days_for_shipping_(real)         -0.000348     0.003432      -0.001631
# Days_for_shipment_(scheduled)    -0.000367     0.000899      -0.000262
# Late_delivery_risk                0.001752     0.001484       0.001077
# ...

# %%
plt.figure(figsize = (15,7))
df['Category_Name'].value_counts().plot(kind='bar')
plt.title('Number of Orders by Category')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.show()

# %%
df['Customer_Segment'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Proportion of Orders by Customer Segment')
plt.ylabel('')
plt.show()

# %%
#Univariate Analysis for Categorical features

df['Delivery_Status'].value_counts().plot(kind='bar')
plt.title('Number of Orders by Category')
plt.xlabel('Category')
plt.ylabel('Number of Orders')
plt.show()

# %%
plt.figure(figsize = (8, 8))
pivot_table = pd.pivot_table(df, values='Sales', index='Category_Name', columns='Customer_Segment', aggfunc=np.sum)
sns.heatmap(pivot_table, cmap='Blues')
plt.title('Total Sales by Category and Customer Segment')
plt.show()

# %%
sizes = df['Category_Name'].value_counts()
labels = sizes.index.tolist()
squarify.plot(sizes=sizes, label=labels, alpha=0.8)
plt.title('Number of Orders by Category')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/f6/0w9l71rj07jdyn9y6cldqdcw0000gn/T/ipykernel_43037/495734723.py in <module>
# ----> 1 import squarify
#       2 sizes = df['Category_Name'].value_counts()
#       3 labels = sizes.index.tolist()
#       4 squarify.plot(sizes=sizes, label=labels, alpha=0.8)
#       5 plt.title('Number of Orders by Category')
#
# ModuleNotFoundError: No module named 'squarify'

# %%
pip install squarify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import squarify
plt.figure(figsize = (20,20))
sizes = df['Category_Name'].value_counts()
labels = sizes.index.tolist()
squarify.plot(sizes=sizes, label=labels, alpha=0.8)
plt.title('Number of Orders by Category')
plt.axis('off')
plt.show()

# %%
df.groupby(['Type', 'Order_Status']).size().unstack().plot(kind='bar')
plt.title('Number of Orders by Customer Segment and Delivery Status')
plt.xlabel('Customer Segment')
plt.ylabel('Number of Orders')
plt.show()

# %%
plt.figure(figsize = (12,20))
df.groupby(['Type', 'Shipping_Mode']).size().unstack().plot(kind='bar')
plt.title('Number of Orders by Type and Shipping Mode')
plt.xlabel('TYPE')
plt.ylabel('Number of Orders')
plt.legend(loc = 'upper left')
plt.show()

# %%
import seaborn as sns
sns.violinplot(x='', y='Sales', data=df)
plt.title('Distribution of Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
sns.catplot(data=df, x="Shipping_Mode", y="Order_Item_Product_Price", kind="box")

# %%
sns.catplot(data=df, x="Shipping_Mode", y="Order_Item_Total", hue="Late_delivery_risk", kind="box")

# %%
g = sns.catplot(
    data=df,
    x="Latitude", y="Market", row="Late_delivery_risk",
    kind="box", orient="h",
    sharex=False, margin_titles=True,
    height=1.5, aspect=4,
)
g.set(xlabel="Latitude", ylabel="")
g.set_titles(row_template="{row_name} class")
for ax in g.axes.flat:
    ax.xaxis.set_major_formatter('{x:.0f}')

# %%
sns.displot(df, x="Sales", kind="kde")

# %%
sns.displot(df, x="Order_Item_Profit_Ratio", hue="Late_delivery_risk", kind="kde", multiple="stack")

# %%
sns.displot(df, x="Sales_per_customer", hue="Late_delivery_risk", kind="kde", multiple="stack")

# %%
cols = ["Shipping_Mode", "Sales_per_customer", "Order_Item_Quantity"]

# Group the data by the Shipping Mode feature
groups = df.groupby("Shipping_Mode")

# Create the 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for name, group in groups:
    ax.scatter(group[cols[0]], group[cols[1]], group[cols[2]], label=name)
ax.set_xlabel(cols[0])
ax.set_ylabel(cols[1])
ax.set_zlabel(cols[2])
plt.title("3D Scatter Plot for Shipping Mode")
plt.legend(loc="best")

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/f6/0w9l71rj07jdyn9y6cldqdcw0000gn/T/ipykernel_43037/2065952515.py in <module>
#       8 ax = fig.add_subplot(111, projection='3d')
#       9 for name, group in groups:
# ---> 10     ax.scatter(group[cols[0]], group[cols[1]], group[cols[2]], label=name)
#      11 ax.set_xlabel(cols[0])
#      12 ax.set_ylabel(cols[1])
#
# IndexError: list index out of range

# %%
sns.displot(df, x="Order_Item_Total", hue="Order_Item_Quantity", multiple="stack")

# %%
df.columns
# Out:
# Index(['Type', 'Delivery_Status', 'Customer_City', 'Customer_Country',
#        'Customer_Segment', 'Customer_State', 'Customer_Street',
#        'Department_Name', 'Market', 'Order_City', 'Order_Country',
#        'Order_Region', 'Order_State', 'Order_Status', 'Product_Name',
#        'Shipping_Mode', 'Category_Id', 'Category_Name', 'Customer_Id',
#        'Department_Id', 'Order_Customer_Id', 'Order_Id',
#        'Order_Item_Cardprod_Id', 'Order_Item_Id', 'Product_Card_Id',
#        'Product_Category_Id', 'Days_for_shipping_(real)',
#        'Days_for_shipment_(scheduled)', 'Late_delivery_risk',
#        'Order_Item_Quantity', 'Benefit_per_order', 'Sales_per_customer',
#        'Latitude', 'Longitude', 'Order_Item_Discount',
#        'Order_Item_Discount_Rate', 'Order_Item_Product_Price',
#        'Order_Item_Profit_Ratio', 'Sales', 'Order_Item_Total',
#        'Order_Profit_Per_Order', 'Product_Price', 'order_date',
#        'shipping_date'],
#       dtype='object')

# %%
df.count()
# Out:
# Type                             180519
# Delivery_Status                  180519
# Customer_City                    180519
# Customer_Country                 180519
# Customer_Segment                 180519
# Customer_State                   180519
# Customer_Street                  180519
# Department_Name                  180519
# Market                           180519
# Order_City                       180519
# Order_Country                    180519
# Order_Region                     180519
# Order_State                      180519
# Order_Status                     180519
# Product_Name                     180519
# Shipping_Mode                    180519
# Category_Id                      180519
# Category_Name                    180519
# Customer_Id                      180519
# Department_Id                    180519
# Order_Customer_Id                180519
# Order_Id                         180519
# Order_Item_Cardprod_Id           180519
# ...
